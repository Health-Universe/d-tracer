# %%
import pandas as pd
import numpy as np

# %%
data = '../data/2022_07_13_WTvsKO_allcompounds_neg.csv'

# %%
df = pd.read_csv(data,header=2)
df
# Out:
#                Compound  Neutral mass (Da)          m/z  Charge  \
# 0      5.09_803.7568m/z                NaN   803.756835       1
# 1      4.97_787.7598m/z                NaN   787.759812       1
# 2      5.05_757.2737m/z                NaN   757.273727       1
# 3     6.29_1020.8231m/z                NaN  1020.823084       1
# 4        5.09_776.6017n         776.601704   797.588528       1
# ...                 ...                ...          ...     ...
# 4901   4.97_558.6103m/z                NaN   558.610340       1
# 4902   6.11_545.0088m/z                NaN   545.008765       1
# 4903   6.17_543.7793m/z                NaN   543.779277       1
# 4904   6.79_536.7195m/z                NaN   536.719456       1
# 4905   6.45_536.6063m/z                NaN   536.606261       1
#
#       Retention time (min)  CCS (angstrom^2)  \
# 0                 5.086917        284.123327
# 1                 4.965617        281.068778
# 2                 5.053083        278.108306
# ...

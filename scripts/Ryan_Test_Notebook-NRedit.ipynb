# %%
import pandas as pd
import numpy as np

# %%
data = '../data/test_data/2022_04_22_NEG_RSL3DAAvsCtrl_test_input.csv'
### Need a way for .py file to ask which file to upload

# %%
df = pd.read_csv(data,header=2)
df.head()
# Out:
#            Compound  Neutral mass (Da)         m/z  Charge  \
# 0  3.38_896.6183m/z                NaN  896.618336       1
# 1  3.38_894.6030m/z                NaN  894.602956       1
# 2  1.45_675.4949m/z                NaN  675.494892       1
# 3  6.36_877.6611m/z                NaN  877.661108       1
# 4  1.05_894.6028m/z                NaN  894.602774       1
#
#    Retention time (min)  CCS (angstrom^2)  Chromatographic peak width (min)  \
# 0              3.379783        295.960433                          0.722133
# 1              3.379783        291.666568                          0.620583
# 2              1.450317        254.211134                          0.775733
# 3              6.361767        296.057245                          0.189000
# 4              1.052567        291.666569                          1.396333
#
#    Identifications     Anova (p)       q Value  ...  Accepted Description  \
# 0                0  3.741218e-11  6.056024e-09  ...                   NaN
# 1                0  4.378042e-10  3.924134e-08  ...                   NaN
# 2                0  7.777021e-10  5.665006e-08  ...                   NaN
# 3                0  1.368948e-09  8.661569e-08  ...                   NaN
# 4                0  2.104757e-09  1.179358e-07  ...                   NaN
#
#   Adducts Formula Score  Fragmentation Score  Mass Error (ppm)  \
# 0     NaN     NaN   NaN                  NaN               NaN
# 1     NaN     NaN   NaN                  NaN               NaN
# 2     NaN     NaN   NaN                  NaN               NaN
# 3     NaN     NaN   NaN                  NaN               NaN
# 4     NaN     NaN   NaN                  NaN               NaN
#
#    Isotope Similarity  Retention Time Error (mins)  dCCS (angstrom^2)  \
# 0                 NaN                          NaN                NaN
# 1                 NaN                          NaN                NaN
# 2                 NaN                          NaN                NaN
# 3                 NaN                          NaN                NaN
# 4                 NaN                          NaN                NaN
#
#    Compound Link
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 56 columns]

# %%
'''Create a list of all column names'''
col = df.columns.tolist()
print(col)

'''Index of columns we wish to keep and analyze'''
keep = [0,2,4,5]

'''Column names we wish to keep and analyze'''
col_keep = []
for i in keep:
    col_keep.append(col[i])
col_keep
# Out:
# ['Compound', 'Neutral mass (Da)', 'm/z', 'Charge', 'Retention time (min)', 'CCS (angstrom^2)', 'Chromatographic peak width (min)', 'Identifications', 'Anova (p)', 'q Value', 'Max Fold Change', 'Highest Mean', 'Lowest Mean', 'Isotope Distribution', 'Maximum Abundance', 'Minimum CV%', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C2', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C3', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C4', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD2', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD3', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD4', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C1.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C2.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C3.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_C4.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD1.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD2.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD3.1', 'NEG_2022_04_22_NR_LIPIDS_HILIC_RD4.1', 'Anova p-value <= 0.05_RSL3vsCtrl', 'Max fold change >= 2_RSL3vsCtrl', 'OPLS_RSL3vsCtrl', 'Anova p-value <= 0.05_DAAvsCtrl', 'OPLS_DAAvsCtrl', 'Anova p-value <= 0.05_RSL3DAAvsControl', 'OPLS_RSL3DAAvsCtrl', 'Anova p-value <= 0.05_DAAvsRSL3', 'OPLS_DAAvsRSL3', 'Anova p-value <= 0.05_DAAvsRSL3DAA', 'OPLS_DAAvsRSL3DAA', 'Anova p-value <= 0.05_RSL3vsRSL3DAA', 'OPLS_RSL3vsRSL3DAA', 'Accepted Compound ID', 'Accepted Description', 'Adducts', 'Formula', 'Score', 'Fragmentation Score', 'Mass Error (ppm)', 'Isotope Similarity', 'Retention Time Error (mins)', 'dCCS (angstrom^2)', 'Compound Link']
# ['Compound', 'm/z', 'Retention time (min)', 'CCS (angstrom^2)']

# %%
'''Make a df of sample mz, rt, ccs, and intensities'''
intensities = col[16:24:1]
df_int = df[intensities][:]
df_int.head()
# Out:
#    NEG_2022_04_22_NR_LIPIDS_HILIC_C1  NEG_2022_04_22_NR_LIPIDS_HILIC_C2  \
# 0                         807.524489                         814.473792
# 1                         395.698872                         455.036308
# 2                        1073.578081                        1099.210797
# 3                          66.967545                          75.642003
# 4                         503.678298                         588.600522
#
#    NEG_2022_04_22_NR_LIPIDS_HILIC_C3  NEG_2022_04_22_NR_LIPIDS_HILIC_C4  \
# 0                         758.517169                         789.944870
# 1                         425.316630                         364.333530
# 2                        1104.813121                        1043.780910
# 3                          57.802987                          63.056480
# 4                         540.177080                         511.645821
#
#    NEG_2022_04_22_NR_LIPIDS_HILIC_RD1  NEG_2022_04_22_NR_LIPIDS_HILIC_RD2  \
# 0                        70081.607655                        71066.416706
# 1                        26922.116741                        27365.744680
# 2                         4376.750665                         4738.135922
# 3                         3347.700848                         3608.845722
# 4                        28758.233544                        28312.631883
#
#    NEG_2022_04_22_NR_LIPIDS_HILIC_RD3  NEG_2022_04_22_NR_LIPIDS_HILIC_RD4
# 0                        75297.146175                        82850.347579
# 1                        29171.586192                        31106.700462
# 2                         4482.084372                         4617.055819
# 3                         3897.165149                         3857.633179
# 4                        28761.967825                        36728.284419

# %%
'''Create new filtered dataframe of important columns'''
df_keep = df[col_keep][:]
df_keep
# Out:
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 0    3.38_896.6183m/z  896.618336              3.379783        295.960433
# 1    3.38_894.6030m/z  894.602956              3.379783        291.666568
# 2    1.45_675.4949m/z  675.494892              1.450317        254.211134
# 3    6.36_877.6611m/z  877.661108              6.361767        296.057245
# 4    1.05_894.6028m/z  894.602774              1.052567        291.666569
# ..                ...         ...                   ...               ...
# 259  5.05_750.6719m/z  750.671905              5.052833        271.947196
# 260  6.17_500.2785m/z  500.278470              6.172767        210.265544
# 261  2.79_274.8797m/z  274.879741              2.793033        141.856174
# 262  2.14_775.4737m/z  775.473692              2.138600        283.624487
# 263  5.24_700.5252m/z  700.525245              5.241833        261.715845
#
# [264 rows x 4 columns]

# %%
'''Define lists and tolerances of each column to compare with itself'''
mz = df_keep['m/z']
mz_tol = 0.005
rt = df_keep['Retention time (min)']
rt_tol = 1e-3
ccs = df_keep['CCS (angstrom^2)']
ccs_tol = .03

'''Initialize a list for indexes to be held for each pair of matched values'''
idxs = []
'''Create nested for loop to compare i with j in each column'''
for i in range(len(df_keep)):
    for j in range(len(df_keep)):
        '''Define checks for each column'''
        check_mz = np.isclose(mz[i], mz[j]+6.03, atol = mz_tol)        
        check_rt = np.isclose(rt[i], rt[j], rt_tol)
        check_ccs = np.isclose(ccs[i], ccs[j], rtol = ccs_tol)
        
        '''Record results of each check (True/False)'''
        checks = [check_mz, check_rt, check_ccs]
        
        '''If all checks are true, append to list of pairs'''
        if all(checks) and i!=j:
            idxs.append([i,j])
            pairs = np.array(idxs)
        else:
            pass
print(pairs)
# Out:
# [[  0   6]
#  [  1 191]
#  [  3  44]
#  [  4  48]
#  [  5  79]
#  [ 14  28]
#  [ 16 176]
#  [ 21  13]
#  [ 22 173]
#  [ 32 232]
#  [ 38 116]
#  [ 43  34]
#  [ 45  26]
#  [ 52  57]
#  [ 59  41]
#  [ 63 108]
#  [ 66 109]
#  [ 88  94]
#  [ 91 202]
#  [185 234]]

# %%
for i in range(len(idxs)):
    print(df_keep.iloc[pairs[i][:]])
### Not sure what we want the end result to look like
# Out:
#            Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 0  3.38_896.6183m/z  896.618336              3.379783        295.960433
# 6  3.38_890.5814m/z  890.581411              3.379783        294.559431
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 1    3.38_894.6030m/z  894.602956              3.379783        291.666568
# 191  3.38_888.5667m/z  888.566727              3.379783        294.569613
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 3   6.36_877.6611m/z  877.661108              6.361767        296.057245
# 44  6.36_871.6240m/z  871.623972              6.361767        296.088953
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 4   1.05_894.6028m/z  894.602774              1.052567        291.666569
# 48  1.05_888.5647m/z  888.564686              1.052567        290.255055
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 5   3.41_882.6029m/z  882.602942              3.413633        290.285011
# 79  3.41_876.5673m/z  876.567271              3.413633        288.870397
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 14  3.41_896.7594m/z  896.759428              3.413633        295.959728
# 28  3.41_890.7210m/z  890.720980              3.413633        295.990112
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 16   3.31_949.6498m/z  949.649753              3.312083        302.810975
# 176  3.31_943.6138m/z  943.613790              3.312083        301.424850
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 21  3.38_978.6214m/z  978.621375              3.379783        312.487434
# 13  3.38_972.5838m/z  972.583766              3.379783        312.514422
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 22   3.38_922.6331m/z  922.633135              3.379783        302.937968
# 173  3.38_916.5968m/z  916.596835              3.379783        304.378659
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 32   5.17_777.6086m/z  777.608593              5.174133        271.777713
# 232  5.17_771.5711m/z  771.571120              5.174133        271.814680
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 38   5.17_805.6395m/z  805.639452              5.174133        280.505380
# 116  5.17_799.6012m/z  799.601204              5.174133        279.068262
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 43  6.36_905.6896m/z  905.689551              6.361767        304.433002
# 34  6.36_899.6525m/z  899.652542              6.361767        303.051947
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 45  3.41_924.6492m/z  924.649174              3.413633        305.747336
# 26  3.41_918.6112m/z  918.611206              3.413633        305.776879
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 52  6.42_874.6423m/z  874.642277              6.415367        300.348589
# 57  6.42_868.6062m/z  868.606189              6.415367        297.533583
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 59  0.90_839.6401m/z  839.640121              0.897417        283.246433
# 41  0.90_833.6022m/z  833.602241              0.897417        283.279547
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 63   1.02_976.6035m/z  976.603511              1.018717        308.312579
# 108  1.02_970.5634m/z  970.563351              1.018717        308.339326
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 66   1.71_808.5985m/z  808.598483                 1.707        279.015710
# 109  1.71_802.5766m/z  802.576598                 1.707        279.050754
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 88  0.90_861.6306m/z  861.630558              0.897417        291.835944
# 94  0.90_855.5932m/z  855.593193              0.897417        291.868361
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 91   5.17_803.6241m/z  803.624068              5.174133        277.568296
# 202  5.17_797.5869m/z  797.586861              5.174133        277.603675
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 185  5.05_761.6128m/z  761.612806              5.052833        270.379867
# 234  5.05_755.5739m/z  755.573920              5.052833        270.418193

# %%
'''add matching indicies to list and make new df of matches with mz, rt, ccs'''
idx_list = []
for i in pairs:
    for j in i:
        idx_list.append(j)
df_pairs = df_keep.loc[df_keep.index[idx_list]]
df_pairs.head()
# Out:
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 0    3.38_896.6183m/z  896.618336              3.379783        295.960433
# 6    3.38_890.5814m/z  890.581411              3.379783        294.559431
# 1    3.38_894.6030m/z  894.602956              3.379783        291.666568
# 191  3.38_888.5667m/z  888.566727              3.379783        294.569613
# 3    6.36_877.6611m/z  877.661108              6.361767        296.057245

# %%
'''combine mz, rt, ccs df with intensities df'''
df_pair_int = df_int.loc[df_int.index[idx_list]]
df_output = pd.concat([df_pairs, df_pair_int], axis="columns")
df_output.head()
# Out:
#              Compound         m/z  Retention time (min)  CCS (angstrom^2)  \
# 0    3.38_896.6183m/z  896.618336              3.379783        295.960433
# 6    3.38_890.5814m/z  890.581411              3.379783        294.559431
# 1    3.38_894.6030m/z  894.602956              3.379783        291.666568
# 191  3.38_888.5667m/z  888.566727              3.379783        294.569613
# 3    6.36_877.6611m/z  877.661108              6.361767        296.057245
#
#      NEG_2022_04_22_NR_LIPIDS_HILIC_C1  NEG_2022_04_22_NR_LIPIDS_HILIC_C2  \
# 0                           807.524489                         814.473792
# 6                          6230.947853                        7050.938150
# 1                           395.698872                         455.036308
# 191                       24933.072880                       28630.142593
# 3                            66.967545                          75.642003
#
#      NEG_2022_04_22_NR_LIPIDS_HILIC_C3  NEG_2022_04_22_NR_LIPIDS_HILIC_C4  \
# 0                           758.517169                         789.944870
# 6                          6336.573548                        6066.191524
# 1                           425.316630                         364.333530
# 191                       26721.374269                       25261.357587
# 3                            57.802987                          63.056480
#
#      NEG_2022_04_22_NR_LIPIDS_HILIC_RD1  NEG_2022_04_22_NR_LIPIDS_HILIC_RD2  \
# 0                          70081.607655                        71066.416706
# 6                          78624.156619                        79707.716865
# 1                          26922.116741                        27365.744680
# 191                        35853.518111                        34602.093161
# 3                           3347.700848                         3608.845722
#
#      NEG_2022_04_22_NR_LIPIDS_HILIC_RD3  NEG_2022_04_22_NR_LIPIDS_HILIC_RD4
# 0                          75297.146175                        82850.347579
# 6                          84702.072838                        92767.029645
# 1                          29171.586192                        31106.700462
# 191                        36199.825133                        39525.548153
# 3                           3897.165149                         3857.633179

# %%
'''export to excel file'''
df_output.to_excel('../data/output_data/rtolccs_ctrlRSL3DAA_test_pairs_output.xlsx')

# %% [markdown]
# #

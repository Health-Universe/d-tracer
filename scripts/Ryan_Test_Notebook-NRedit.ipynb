# %%
import pandas as pd
import numpy as np

# %%
data = '../data/2022_07_13_WTvsKO_allcompounds_neg.csv'
### Need a way for .py file to ask which file to upload

# %%
df = pd.read_csv(data,header=2)
df.head()
# Out:
#             Compound  Neutral mass (Da)          m/z  Charge  \
# 0   5.09_803.7568m/z                NaN   803.756835       1
# 1   4.97_787.7598m/z                NaN   787.759812       1
# 2   5.05_757.2737m/z                NaN   757.273727       1
# 3  6.29_1020.8231m/z                NaN  1020.823084       1
# 4     5.09_776.6017n         776.601704   797.588528       1
#
#    Retention time (min)  CCS (angstrom^2)  Chromatographic peak width (min)  \
# 0              5.086917        284.123327                          0.189000
# 1              4.965617        281.068778                          0.121317
# 2              5.053083        278.108306                          0.121300
# 3              6.294300        323.846316                          0.121317
# 4              5.086917        284.160322                          0.397767
#
#    Identifications     Anova (p)       q Value  ...  Accepted Description  \
# 0                0  0.000000e+00  0.000000e+00  ...                   NaN
# 1                0  0.000000e+00  0.000000e+00  ...                   NaN
# 2                0  1.110223e-16  2.568849e-14  ...                   NaN
# 3                0  1.110223e-16  2.568849e-14  ...                   NaN
# 4                0  1.110223e-16  2.568849e-14  ...                   NaN
#
#         Adducts Formula Score  Fragmentation Score Mass Error (ppm)  \
# 0           NaN     NaN   NaN                  NaN              NaN
# 1           NaN     NaN   NaN                  NaN              NaN
# 2           NaN     NaN   NaN                  NaN              NaN
# 3           NaN     NaN   NaN                  NaN              NaN
# 4  M-H, M+Na-2H     NaN   NaN                  NaN              NaN
#
#    Isotope Similarity  Retention Time Error (mins)  dCCS (angstrom^2)  \
# 0                 NaN                          NaN                NaN
# 1                 NaN                          NaN                NaN
# 2                 NaN                          NaN                NaN
# 3                 NaN                          NaN                NaN
# 4                 NaN                          NaN                NaN
#
#    Compound Link
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 77 columns]

# %%
'''Create a list of all column names'''
col = df.columns.tolist()
print(col)

'''Index of columns we wish to keep and analyze'''
keep = [0,2,4,5]

'''Column names we wish to keep and analyze'''
col_keep = []
for i in keep:
    col_keep.append(col[i])
col_keep
# Out:
# ['Compound', 'Neutral mass (Da)', 'm/z', 'Charge', 'Retention time (min)', 'CCS (angstrom^2)', 'Chromatographic peak width (min)', 'Identifications', 'Anova (p)', 'q Value', 'Max Fold Change', 'Highest Mean', 'Lowest Mean', 'Isotope Distribution', 'Maximum Abundance', 'Minimum CV%', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD2', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R2.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD1.1', 'NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD2.1', 'Anova p-value KOvsWT DAA<= 0.05', 'Max fold change WT vsKO DAA>= 2', 'Anova p-value WT vs KO RD <= 0.05', 'Max fold change WT vs KO RD >= 2', 'Anova p-value WT vs KO R<= 0.05', 'Max fold change WT vs KO R >= 2', 'Anova p-value KO daa vs daarsl3 <= 0.05', 'Max fold change KO daa vs daarsl3  >= 2', 'Anova p-value WT daa vs daarsl3 <= 0.05', 'Max fold change WT daa vs daarsl3 >= 2', 'Anova p-value <= 0.05 ko c vs dr', 'Max fold change >= 2 ko c vs dr', 'Anova p-value <= 0.05 wt c vs dr', 'Max fold change >= 2 wt c vs dr', 'Anova p-value <= 0.05 ko c vs d', 'Max fold change >= 2 ko c vs d', 'Anova p-value <= 0.05 wt c vs d', 'Max fold change >= 2 wt c vs d', 'Accepted Compound ID', 'Accepted Description', 'Adducts', 'Formula', 'Score', 'Fragmentation Score', 'Mass Error (ppm)', 'Isotope Similarity', 'Retention Time Error (mins)', 'dCCS (angstrom^2)', 'Compound Link']
# ['Compound', 'm/z', 'Retention time (min)', 'CCS (angstrom^2)']

# %%
'''Make a df of sample mz, rt, ccs, and intensities'''
intensities = col[16:32:1]
df_int = df[intensities][:100]
df_int.head()
# Out:
#    NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C1  NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C2  \
# 0                                0.0000                              0.000000
# 1                                0.0000                              0.000000
# 2                                0.0000                              0.000000
# 3                                0.0000                              0.000000
# 4                             3387.9089                           3405.940996
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D1  NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D2  \
# 0                            407.654500                            420.461276
# 1                            369.250626                            370.267982
# 2                            307.498293                            286.800966
# 3                            129.718470                            118.280514
# 4                          24694.959150                          25348.674536
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R1  NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R2  \
# 0                              0.000000                               0.00000
# 1                              0.000000                               0.00000
# 2                              0.000000                               0.00000
# 3                              0.000000                               0.00000
# 4                           3275.245776                            3327.04054
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD1  \
# 0                             385.107511
# 1                             313.076980
# 2                             283.482355
# 3                             127.239392
# 4                           24091.229533
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD2  \
# 0                             365.595946
# 1                             303.813405
# 2                             293.671320
# 3                             127.443142
# 4                           23828.255412
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C1  NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C2  \
# 0                              0.000000                              0.000000
# 1                              0.000000                              0.000000
# 2                              0.000000                              0.000000
# 3                              0.000000                              0.000000
# 4                           2856.702211                           2874.484875
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D1  NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D2  \
# 0                            449.254529                            453.605111
# 1                            257.533814                            262.038949
# 2                            182.472212                            195.835673
# 3                            188.296237                            196.759510
# 4                          26770.898125                          26762.333436
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R1  NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R2  \
# 0                              0.000000                              0.000000
# 1                              0.000000                              0.000000
# 2                              0.000000                              0.000000
# 3                              0.000000                              0.000000
# 4                           2593.152599                           2638.692648
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD1  \
# 0                             423.162041
# 1                             226.896927
# 2                             182.637573
# 3                             162.551127
# 4                           25546.983784
#
#    NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD2
# 0                             420.887528
# 1                             250.294353
# 2                             174.141373
# 3                             163.469014
# 4                           25205.844765

# %%
'''Create new filtered dataframe of important columns'''
df_keep = df[col_keep][:100]
df_keep
# Out:
#              Compound          m/z  Retention time (min)  CCS (angstrom^2)
# 0    5.09_803.7568m/z   803.756835              5.086917        284.123327
# 1    4.97_787.7598m/z   787.759812              4.965617        281.068778
# 2    5.05_757.2737m/z   757.273727              5.053083        278.108306
# 3   6.29_1020.8231m/z  1020.823084              6.294300        323.846316
# 4      5.09_776.6017n   797.588528              5.086917        284.160322
# ..                ...          ...                   ...               ...
# 95     0.62_369.3644n   390.340211              0.620983        202.255685
# 96     0.78_843.6165n   878.585879              0.776150        293.149110
# 97     4.31_585.8916n   606.879107              4.311150        196.631411
# 98   3.16_898.3094m/z   898.309447              3.157350        302.473096
# 99     0.90_885.6479n   922.634293              0.897450        302.352505
#
# [100 rows x 4 columns]

# %%
'''Define lists and tolerances of each column to compare with itself'''
mz = df_keep['m/z']
mz_tol = 1e-4
rt = df_keep['Retention time (min)']
rt_tol = 1e-3
ccs = df_keep['CCS (angstrom^2)']
ccs_tol = 1e-3

'''Initialize a list for indexes to be held for each pair of matched values'''
idxs = []
'''Create nested for loop to compare i with j in each column'''
for i in range(len(df_keep)):
    for j in range(len(df_keep)):
        '''Define checks for each column'''
        check_mz = np.isclose(mz[i], mz[j]+6.02, mz_tol)        
        check_rt = np.isclose(rt[i], rt[j], rt_tol)
        check_ccs = np.isclose(ccs[i], ccs[j], ccs_tol)
        
        '''Record results of each check (True/False)'''
        checks = [check_mz, check_rt, check_ccs]
        
        '''If all checks are true, append to list of pairs'''
        if all(checks) and i!=j:
            idxs.append([i,j])
            pairs = np.array(idxs)
        else:
            pass
print(pairs)
# Out:
# [[14 45]
#  [16 15]
#  [20 18]
#  [28 24]
#  [38 26]
#  [44 10]
#  [54 75]
#  [56 30]
#  [70  4]
#  [92 90]]

# %%
for i in range(len(idxs)):
    print(df_keep.iloc[pairs[i][:]])
### Not sure what we want the end result to look like
# Out:
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 14  5.05_761.6121m/z  761.612050              5.053083        278.080052
# 45    5.05_756.6069n  755.566165              5.053083        278.119515
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 16  3.16_899.8980m/z  899.897980               3.15735        302.465024
# 15  3.16_893.9342m/z  893.934249               3.15735        302.495477
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 20  5.05_342.4169m/z  342.416944              5.053083        190.202882
# 18  5.05_336.3790m/z  336.378983              5.053083        190.331918
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 28  0.93_895.0867m/z  895.086674                0.9313        293.065615
# 24  0.93_889.0476m/z  889.047570                0.9313        293.095816
#           Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 38  6.48_830.6734n  865.662612                6.4833        293.216707
# 26  6.48_838.6401n  859.626006                6.4833        293.248974
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 44  6.45_863.6493m/z  863.649306               6.44945        290.082848
# 10    6.45_822.6419n  857.612076               6.44945        290.114921
#           Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 54  6.45_870.7045n  905.692635               6.44945        302.435814
# 75  6.45_878.6684n  899.655184               6.44945        302.466256
#           Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 56  5.09_778.6152n  777.607923              5.086917        274.824574
# 30  5.09_734.5909n  771.572132              5.086917        274.861945
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 70  5.09_803.6260m/z  803.626033              5.086917        284.124105
# 4     5.09_776.6017n  797.588528              5.086917        284.160322
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 92  5.05_761.7419m/z  761.741906              5.053083        278.079211
# 90    5.05_734.7163n  755.703718              5.053083        278.118610

# %%
'''add matching indicies to list and make new df of matches with mz, rt, ccs'''
idx_list = []
for i in pairs:
    for j in i:
        idx_list.append(j)
df_pairs = df_keep.loc[df_keep.index[idx_list]]
df_pairs.head()
# Out:
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)
# 14  5.05_761.6121m/z  761.612050              5.053083        278.080052
# 45    5.05_756.6069n  755.566165              5.053083        278.119515
# 16  3.16_899.8980m/z  899.897980              3.157350        302.465024
# 15  3.16_893.9342m/z  893.934249              3.157350        302.495477
# 20  5.05_342.4169m/z  342.416944              5.053083        190.202882

# %%
'''combine mz, rt, ccs df with intensities df'''
df_pair_int = df_int.loc[df_int.index[idx_list]]
df_output = pd.concat([df_pairs, df_pair_int], axis="columns")
df_output.head()
# Out:
#             Compound         m/z  Retention time (min)  CCS (angstrom^2)  \
# 14  5.05_761.6121m/z  761.612050              5.053083        278.080052
# 45    5.05_756.6069n  755.566165              5.053083        278.119515
# 16  3.16_899.8980m/z  899.897980              3.157350        302.465024
# 15  3.16_893.9342m/z  893.934249              3.157350        302.495477
# 20  5.05_342.4169m/z  342.416944              5.053083        190.202882
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C1  \
# 14                            344.694030
# 45                          10104.471419
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_C2  \
# 14                            346.519756
# 45                           9758.085041
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D1  \
# 14                          29914.321156
# 45                          40949.186367
# 16                            320.298388
# 15                            255.139101
# 20                             37.936238
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_D2  \
# 14                          30126.459092
# 45                          41034.038834
# 16                            291.122259
# 15                            252.438602
# 20                             38.278801
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R1  \
# 14                            327.583545
# 45                           9463.885209
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_R2  \
# 14                            322.763704
# 45                           9806.965957
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD1  \
# 14                           28831.778489
# 45                           39326.224454
# 16                             288.235085
# 15                             248.483765
# 20                              35.389910
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_KO_RD2  \
# 14                           28995.641196
# 45                           39696.824424
# 16                             321.229091
# 15                             293.242786
# 20                              31.514619
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C1  \
# 14                            566.946809
# 45                           9378.739955
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_C2  \
# 14                            497.744051
# 45                           9352.862476
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D1  \
# 14                          23269.250204
# 45                          32623.954491
# 16                            232.314163
# 15                            209.950323
# 20                             28.595740
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_D2  \
# 14                          24470.166661
# 45                          34517.143737
# 16                            277.366148
# 15                            237.755500
# 20                             31.986394
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R1  \
# 14                            511.791139
# 45                           8604.682340
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_R2  \
# 14                            503.041123
# 45                           8469.671476
# 16                              0.000000
# 15                              0.000000
# 20                              0.000000
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD1  \
# 14                           23047.021804
# 45                           32522.262396
# 16                             242.553709
# 15                             203.491538
# 20                              25.260168
#
#     NEG_2022_07_12_NR_LIPIDS_HILIC_WT_RD2
# 14                           22961.231380
# 45                           32620.870473
# 16                             249.178319
# 15                             214.805597
# 20                              24.858283

# %%
'''export to excel file'''
df_output.to_excel('../data/test_output.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 '''export to excel file'''
# ----> 2 df_output.to_excel('../data/test_output.xlsx')
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py:49, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      36 def __init__(
#      37     self,
#      38     path,
#    (...)
#      47 ):
#      48     # Use the openpyxl module as the Excel writer.
# ---> 49     from openpyxl.workbook import Workbook
#      51     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      53     super().__init__(
#      54         path,
#      55         mode=mode,
#    (...)
#      58         engine_kwargs=engine_kwargs,
#      59     )
#
# ModuleNotFoundError: No module named 'openpyxl'
